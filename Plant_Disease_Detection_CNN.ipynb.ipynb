# %%
import os

# Setting your credentials directly from your screenshots
os.environ['KAGGLE_USERNAME'] = "yarlagaddapradeepthi"
os.environ['KAGGLE_KEY'] = "cbcf6a28917fb7876ad74f6379766435"

# 1. Install/Update Kaggle tools
# !pip install -q kaggle

# 2. Download the 3GB dataset
print("Downloading dataset... this may take a minute.")
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset

# 3. Unzip the file into a folder named 'dataset'
print("Unzipping images...")
# !unzip -q new-plant-diseases-dataset.zip -d dataset/

print("✅ Success! Your data is ready in the 'dataset' folder.")
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset
# License(s): copyright-authors
# ...
# 100% 2.69G/2.70G [00:40<00:00, 184MB/s]
# 100% 2.70G/2.70G [00:40<00:00, 70.8MB/s]
# Unzipping images...
# ✅ Success! Your data is ready in the 'dataset' folder.

# %%
import os
print(os.listdir("dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train"))
# Out:
# ['Peach___healthy', 'Blueberry___healthy', 'Grape___healthy', 'Tomato___Septoria_leaf_spot', 'Apple___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Leaf_Mold', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Tomato___Early_blight', 'Squash___Powdery_mildew', 'Potato___Early_blight', 'Tomato___Tomato_mosaic_virus', 'Corn_(maize)___healthy', 'Strawberry___Leaf_scorch', 'Apple___Apple_scab', 'Tomato___Late_blight', 'Tomato___Bacterial_spot', 'Tomato___healthy', 'Cherry_(including_sour)___healthy', 'Soybean___healthy', 'Pepper,_bell___Bacterial_spot', 'Grape___Esca_(Black_Measles)', 'Potato___Late_blight', 'Strawberry___healthy', 'Apple___Cedar_apple_rust', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Tomato___Target_Spot', 'Corn_(maize)___Common_rust_', 'Raspberry___healthy', 'Peach___Bacterial_spot', 'Pepper,_bell___healthy', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Potato___healthy', 'Grape___Black_rot', 'Apple__
# ...

# %%
# !nvidia-smi
# Out:
# Sat Feb 21 07:18:20 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
os.environ['KAGGLE_USERNAME'] = "yarlagaddapradeepthi"
os.environ['KAGGLE_KEY'] = "cbcf6a28917fb7876ad74f6379766435"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os

# 1. SETUP PATHS
base_path = "dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)"
train_dir = os.path.join(base_path, "train")
val_dir = os.path.join(base_path, "valid")

# 2. LOAD DATA
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(128, 128),
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    image_size=(128, 128),
    batch_size=32
)

# 3. BUILD THE MODEL
model = models.Sequential([
    layers.Rescaling(1./255, input_shape=(128, 128, 3)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(len(train_ds.class_names), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 4. START TRAINING
print("🚀 Training starting... This will take a few minutes per epoch.")
model.fit(train_ds, validation_data=val_ds, epochs=5)

# 5. SAVE
model.save("plant_disease_model.h5")
print("✅ Done! Model saved as plant_disease_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipython-input-1477728493.py in <cell line: 0>()
#       9
#      10 # 2. LOAD DATA
# ---> 11 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#      12     train_dir,
#      13     image_size=(128, 128),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     230     if seed is None:
#     231         seed = np.random.randint(1e6)
# --> 232     image_paths, labels, class_names = dataset_utils.index_directory(
#     233         directory,
#     234         labels,
#
# ...

# %%
# !find . -maxdepth 4 -type d
# Out:
# .
# ./.config
# ./.config/logs
# ./.config/logs/2026.02.06
# ./.config/configurations
# ./sample_data

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os
import glob

# Automatically find the path to train and valid folders
train_paths = glob.glob('**/train', recursive=True)
val_paths = glob.glob('**/valid', recursive=True)

if not train_paths:
    print("❌ Dataset not found. Please re-run your download/unzip code first!")
else:
    train_dir = train_paths[0]
    val_dir = val_paths[0]
    print(f"✅ Found folders!\nTrain: {train_dir}\nValid: {val_dir}")

    # Load data with verified paths
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        train_dir, image_size=(128, 128), batch_size=32
    )
    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        val_dir, image_size=(128, 128), batch_size=32
    )
# Out:
# ❌ Dataset not found. Please re-run your download/unzip code first!

# %%
import os

# Set credentials (your unique token)
os.environ['KAGGLE_USERNAME'] = "yarlagaddapradeepthi"
os.environ['KAGGLE_KEY'] = "cbcf6a28917fb7876ad74f6379766435"

# Download and Unzip
print("Fetching the dataset...")
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset
print("Unzipping... please wait a moment.")
# !unzip -q new-plant-diseases-dataset.zip -d dataset/
print("✅ Dataset is back!")
# Out:
# Fetching the dataset...
# Dataset URL: https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset
# License(s): copyright-authors
# ...
# 100% 2.69G/2.70G [00:31<00:00, 233MB/s]
# 100% 2.70G/2.70G [00:31<00:00, 90.8MB/s]
# Unzipping... please wait a moment.
# ✅ Dataset is back!

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import os
import glob

# Automatically find the path to train and valid folders
train_path_list = glob.glob('**/train', recursive=True)
val_path_list = glob.glob('**/valid', recursive=True)

if not train_path_list:
    print("❌ Still can't find folders. Check the folder icon on the left!")
else:
    train_dir = train_path_list[0]
    val_dir = val_path_list[0]

    # Load data
    train_ds = tf.keras.utils.image_dataset_from_directory(
        train_dir, image_size=(128, 128), batch_size=32
    )
    val_ds = tf.keras.utils.image_dataset_from_directory(
        val_dir, image_size=(128, 128), batch_size=32
    )

    # Build and Train
    model = models.Sequential([
        layers.Rescaling(1./255, input_shape=(128, 128, 3)),
        layers.Conv2D(32, (3,3), activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64, (3,3), activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(len(train_ds.class_names), activation='softmax')
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    print("🚀 Training starting on GPU...")
    model.fit(train_ds, validation_data=val_ds, epochs=5)

    model.save("plant_disease_model.h5")
    print("⭐ Success! Model saved as plant_disease_model.h5")
# Out:
# Found 70295 files belonging to 38 classes.
# Found 17572 files belonging to 38 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 🚀 Training starting on GPU...
# Epoch 1/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 67s 28ms/step - accuracy: 0.5772 - loss: 1.5034 - val_accuracy: 0.8365 - val_loss: 0.5213
# Epoch 2/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 56s 26ms/step - accuracy: 0.8888 - loss: 0.3482 - val_accuracy: 0.9112 - val_loss: 0.2817
# Epoch 3/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 58s 26ms/step - accuracy: 0.9378 - loss: 0.1914 - val_accuracy: 0.8886 - val_loss: 0.3817
# Epoch 4/5
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 58s 26ms/step - accuracy: 0.9547 - loss: 0.1338 - val_accuracy: 0.8987 - val_loss: 0.3665
# Epoch 5/5
# ...

# %%
with open('plant_disease_model.tflite', 'wb') as f:
  f.write(tflite_model)
